# %%
import requests
import json
import pandas as pd
def weather(url):
    headers = {
        'x-rapidapi-key': "76d2396840mshc562c26618d33a2p1fb1e6jsn95b66aa3ea3c",
        'x-rapidapi-host': "national-weather-service.p.rapidapi.com"
        }

    response = requests.request("GET", url, headers=headers)
    return response

# %%
url = "https://national-weather-service.p.rapidapi.com/points/39.196005,-121.1910659"
firstPull = weather(url)

info = firstPull.json()
fore = info['properties']['forecast']
foreHour= info['properties']['forecastHourly']

forecast = weather(fore)
forecastHour = weather(foreHour)

# %%
def pullData(item):
    Jsoned = item.json()
    DataFramed = pd.DataFrame(Jsoned["properties"]['periods'])
    return DataFramed

# %%
forcastDay = pullData(forecast)
forcast_Hour = pullData(forecastHour)
# Out:
#      number name                  startTime                    endTime  \
# 0         1       2020-12-14T21:00:00-08:00  2020-12-14T22:00:00-08:00
# 1         2       2020-12-14T22:00:00-08:00  2020-12-14T23:00:00-08:00
# 2         3       2020-12-14T23:00:00-08:00  2020-12-15T00:00:00-08:00
# 3         4       2020-12-15T00:00:00-08:00  2020-12-15T01:00:00-08:00
# 4         5       2020-12-15T01:00:00-08:00  2020-12-15T02:00:00-08:00
# ..      ...  ...                        ...                        ...
# 151     152       2020-12-21T04:00:00-08:00  2020-12-21T05:00:00-08:00
# 152     153       2020-12-21T05:00:00-08:00  2020-12-21T06:00:00-08:00
# 153     154       2020-12-21T06:00:00-08:00  2020-12-21T07:00:00-08:00
# 154     155       2020-12-21T07:00:00-08:00  2020-12-21T08:00:00-08:00
# 155     156       2020-12-21T08:00:00-08:00  2020-12-21T09:00:00-08:00
#
#      isDaytime  temperature temperatureUnit temperatureTrend windSpeed  \
# 0        False           38               F             None     5 mph
# 1        False           38               F             None     7 mph
# 2        False           38               F             None     7 mph
# 3        False           38               F             None     7 mph
# 4        False           36               F             None     8 mph
# ..         ...          ...             ...              ...       ...
# 151      False           44               F             None     3 mph
# 152      False           42               F             None     3 mph
# 153       True           41               F             None     3 mph
# 154       True           41               F             None     2 mph
# 155       True           45               F             None     2 mph
#
#     windDirection                                               icon  \
# 0             ENE  https://api.weather.gov/icons/land/night/sct?s...
# 1             ENE  https://api.weather.gov/icons/land/night/few?s...
# 2             ENE  https://api.weather.gov/icons/land/night/few?s...
# 3             ENE  https://api.weather.gov/icons/land/night/few?s...
# 4              NE  https://api.weather.gov/icons/land/night/few?s...
# ..            ...                                                ...
# 151             E  https://api.weather.gov/icons/land/night/sct?s...
# 152             E  https://api.weather.gov/icons/land/night/sct?s...
# 153             E  https://api.weather.gov/icons/land/day/sct?siz...
# 154             E  https://api.weather.gov/icons/land/day/bkn?siz...
# 155             E  https://api.weather.gov/icons/land/day/bkn?siz...
#
#      shortForecast detailedForecast
# 0    Partly Cloudy
# 1     Mostly Clear
# 2     Mostly Clear
# 3     Mostly Clear
# 4     Mostly Clear
# ..             ...              ...
# 151  Partly Cloudy
# 152  Partly Cloudy
# 153   Mostly Sunny
# 154   Partly Sunny
# 155   Partly Sunny
#
# [156 rows x 13 columns]
