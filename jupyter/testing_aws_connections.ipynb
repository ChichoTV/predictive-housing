# %%
import pandas as pd
import sqlalchemy

# %%
df=pd.read_csv('../2017-2018_Sac_Housing_Data.csv')
df.head()
# Out:
#          Community    ZIP  Sales  median2017  median2018  Change
# 0       Sacramento  95815     27      212500      220000     3.5
# 1       Sacramento  95824     17      195000      222000    13.8
# 2       Sacramento  95838     42      205000      232000    13.2
# 3  North Highlands  95660     38      240000      235000    -2.1
# 4       Sacramento  95820     51      235000      269000    14.5

# %%
db_info={
    'host_name': "test.cqvtwcxuk2vw.us-west-1.rds.amazonaws.com",
    'user_name': "Taylor",
    'password':"Kirby8295!",
    'db_name':"postgres",
    'port': '5432'
}

# %%
connection_string='postgresql://Taylor:Kirby8295!@test.cqvtwcxuk2vw.us-west-1.rds.amazonaws.com:5432/postgres'

# %%
db=sqlalchemy.create_engine(connection_string)
connection=db.connect()

# %%
tester=connection.execute('SELECT * FROM regions')

# %%
for item in tester:
    print(item)
# Out:
# (99999, '98847; WA; Wenatchee; Chelan County; Peshastin', 98847)
# (99998, '98846; WA; Okanogan County; Pateros', 98846)
# (99997, '98845; WA; Wenatchee; Douglas County; Palisades', 98845)
# (99996, '98844; WA; Okanogan County; Oroville', 98844)
# (99995, '98843; WA; Wenatchee; Douglas County; Orondo', 98843)
# (99994, '98841; WA; Okanogan County; Omak', 98841)
# (99993, '98840; WA; Okanogan County; Okanogan', 98840)
# (99992, '98837; WA; Moses Lake; Grant County', 98837)
# (99991, '98836; WA; Wenatchee; Chelan County', 98836)
# (99990, '98834; WA; Okanogan County; Methow', 98834)
# (99989, '98833; WA; Okanogan County; Mazama', 98833)
# (99988, '98832; WA; Moses Lake; Grant County; Krupp', 98832)
# (99987, '98831; WA; Wenatchee; Chelan County; Manson', 98831)
# (99986, '98830; WA; Wenatchee; Douglas County; Mansfield', 98830)
# (99985, '98829; WA; Okanogan County; Okanogan', 98829)
# (99984, '98828; WA; Wenatchee; Chelan County; Malaga', 98828)
# ...

# %%
df.to_sql(name='census', con=db, if_exists='append', index=True)

# %%
tester=connection.execute('SELECT * FROM census')
for item in tester:
    print(item)
# Out:
# (0, 'Sacramento', 95815, 27, 212500, 220000, 3.5)
# (1, 'Sacramento', 95824, 17, 195000, 222000, 13.8)
# (2, 'Sacramento', 95838, 42, 205000, 232000, 13.2)
# (3, 'North Highlands', 95660, 38, 240000, 235000, -2.1)
# (4, 'Sacramento', 95820, 51, 235000, 269000, 14.5)
# (5, 'Sacramento', 95832, 16, 255000, 273500, 7.3)
# (6, 'Sacramento', 95822, 59, 269000, 273500, 1.7)
# (7, 'Sacramento', 95823, 67, 256500, 277000, 8.0)
# (8, 'Pollock Pines', 95726, 16, 300100, 280000, -6.7)
# (9, 'Rio Linda', 95673, 16, 275000, 292500, 6.4)
# (10, 'Sacramento', 95825, 13, 242500, 295000, 21.6)
# (11, 'Sacramento', 95833, 34, 276500, 295000, 6.7)
# (12, 'Sacramento', 95828, 39, 278000, 295000, 6.1)
# (13, 'Sacramento', 95842, 23, 275000, 300000, 9.1)
# (14, 'Rancho Cordova', 95670, 48, 315000, 307000, -2.5)
# (15, 'Sacramento', 95821, 30, 329500, 315000, -4.4)
# (16, 'Sacramento', 95827, 12, 307500, 316000, 2.8)
# (17, 'Citrus Heights', 95621, 32, 306000, 316500, 3.4)
# ...
