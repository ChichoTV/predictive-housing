# %%
import pandas as pd
import sqlalchemy
import quandl
import requests

# %%
df1=pd.read_csv('../zillow_regions_parsed.csv')
df2=pd.read_csv('../census_data_2018.csv',low_memory=False)
df3=pd.read_csv('../cleaned_zillow_indicators.csv')

# %%
# df3=df3.drop('Unnamed: 0',axis=1)
df3
# Out:
#   indicator_id                        indicator     category
# 0         Z5BR  ZHVI 5+ Bedroom Time Series ($)  Home values
# 1         Z4BR   ZHVI 4-Bedroom Time Series ($)  Home values
# 2         Z3BR   ZHVI 3-Bedroom Time Series ($)  Home values
# 3         Z2BR   ZHVI 2-Bedroom Time Series ($)  Home values
# 4         Z1BR   ZHVI 1-Bedroom Time Series ($)  Home values

# %%
connection_string='postgresql://MasterUser:BootCamp123@database-1.cqvtwcxuk2vw.us-west-1.rds.amazonaws.com:5432/postgres'

# %%
db=sqlalchemy.create_engine(connection_string)
connection=db.connect()

# %%
df1.to_sql(name='regions', con=db, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-4a25719d426a> in <module>
# ----> 1 df1.to_sql(name='regions', con=db, if_exists='append', index=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
# ...

# %%
df2.to_sql(name='census_2018', con=db, if_exists='append', index=True)

# %%
df3.to_sql(name='indicators', con=db, if_exists='append', index=True)

# %%
response=requests.get('https://www.quandl.com/api/v3/datatables/ZILLOW/DATA?indicator_id=Z1BR&region_id=99999&api_key=74g3zUso-i7jUjwzzsgh')

# %%
response.json()
# Out:
# {'datatable': {'data': [['Z1BR', '99999', '2020-10-31', 331882.0],
#    ['Z1BR', '99999', '2020-09-30', 324003.0],
#    ['Z1BR', '99999', '2020-08-31', 319752.0],
#    ['Z1BR', '99999', '2020-07-31', 285354.0],
#    ['Z1BR', '99999', '2020-06-30', 283187.0],
#    ['Z1BR', '99999', '2020-05-31', 281508.0],
#    ['Z1BR', '99999', '2020-04-30', 267385.0],
#    ['Z1BR', '99999', '2020-03-31', 266354.0],
#    ['Z1BR', '99999', '2020-02-29', 266014.0],
#    ['Z1BR', '99999', '2020-01-31', 266621.0],
#    ['Z1BR', '99999', '2019-12-31', 266846.0],
#    ['Z1BR', '99999', '2019-11-30', 267025.0],
#    ['Z1BR', '99999', '2019-10-31', 266383.0],
#    ['Z1BR', '99999', '2019-09-30', 266726.0],
#    ['Z1BR', '99999', '2019-08-31', 264321.0],
#    ['Z1BR', '99999', '2019-07-31', 262944.0],
#    ['Z1BR', '99999', '2019-06-30', 259566.0],
#    ['Z1BR', '99999', '2019-05-31', 256888.0],
#    ['Z1BR', '99999', '2019-04-30', 253493.0],
#    ['Z1BR', '99999', '2019-03-31', 252424.0],
# ...
